# %%
import pandas as pd

# %%
player_data = pd.read_excel('player_data.xlsx')
players = pd.read_excel('Players.xlsx')
Seasons_Stats = pd.read_excel('Seasons_Stats.xlsx')

# %%
player_data.head(50)
# Out:
#                    name  year_start  year_end position     height  weight  \
# 0        Alaa Abdelnaby        1991      1995      F-C 2023-06-10   240.0
# 1       Zaid Abdul-Aziz        1969      1978      C-F 2023-06-09   235.0
# 2   Kareem Abdul-Jabbar        1970      1989        C 2023-07-02   225.0
# 3    Mahmoud Abdul-Rauf        1991      2001        G 2023-06-01   162.0
# 4     Tariq Abdul-Wahad        1998      2003        F 2023-06-06   223.0
# 5   Shareef Abdur-Rahim        1997      2008        F 2023-06-09   225.0
# 6         Tom Abernethy        1977      1981        F 2023-06-07   220.0
# 7           Forest Able        1957      1957        G 2023-06-03   180.0
# 8        John Abramovic        1947      1948        F 2023-06-03   195.0
# 9          Alex Abrines        2017      2018      G-F 2023-06-06   190.0
# 10           Alex Acker        2006      2009        G 2023-06-05   185.0
# 11         Don Ackerman        1954      1954        G 2000-06-01   183.0
# ...

# %%
players.head(50)
# Out:
#               Player  height  weight  \
# 0    Curly Armstrong   180.0    77.0
# 1       Cliff Barker   188.0    83.0
# 2      Leo Barnhorst   193.0    86.0
# 3         Ed Bartels   196.0    88.0
# 4        Ralph Beard   178.0    79.0
# 5         Gene Berce   180.0    79.0
# 6      Charlie Black   196.0    90.0
# 7        Nelson Bobb   183.0    77.0
# 8    Jake Bornheimer   196.0    90.0
# 9       Vince Boryla   196.0    95.0
# 10         Don Boven   193.0    95.0
# 11     Harry Boykoff   208.0   102.0
# 12       Joe Bradley   190.0    79.0
# 13       Bob Brannum   196.0    97.0
# 14        Carl Braun   196.0    81.0
# 15     Frankie Brian   185.0    81.0
# 16  Price Brookfield   193.0    83.0
# 17         Bob Brown   193.0    92.0
# 18        Jim Browne   208.0   106.0
# 19        Walt Budko   196.0    99.0
# 20    Jack Burmaster   190.0    86.0
# 21      Tommy Byrnes   190.0    79.0
# 22      Bill Calhoun   190.0    81.0
# 23       Don Carlson   183.0    77.0
# ...

# %%
Seasons_Stats.head(50)
# Out:
#       Year            Player  Pos   Age   Tm     G    TS%    FTr  OWS  DWS  \
# 0   1950.0   Curly Armstrong  G-F  31.0  FTW  63.0  0.368  0.467 -0.1  3.6
# 1   1950.0      Cliff Barker   SG  29.0  INO  49.0  0.435  0.387  1.6  0.6
# 2   1950.0     Leo Barnhorst   SF  25.0  CHS  67.0  0.394  0.259  0.9  2.8
# 3   1950.0        Ed Bartels    F  24.0  TOT  15.0  0.312  0.395 -0.5 -0.1
# 4   1950.0        Ed Bartels    F  24.0  DNN  13.0  0.308  0.378 -0.5 -0.1
# 5   1950.0        Ed Bartels    F  24.0  NYK   2.0  0.376  0.750  0.0  0.0
# 6   1950.0       Ralph Beard    G  22.0  INO  60.0  0.422  0.301  3.6  1.2
# 7   1950.0        Gene Berce  G-F  23.0  TRI   3.0  0.275  0.313 -0.1  0.0
# 8   1950.0     Charlie Black  F-C  28.0  TOT  65.0  0.346  0.395 -2.2  5.0
# 9   1950.0     Charlie Black  F-C  28.0  FTW  36.0  0.362  0.480 -0.7  2.2
# 10  1950.0     Charlie Black  F-C  28.0  AND  29.0  0.326  0.296 -1.5  2.8
# ...

# %%
Two_Thousands_Stats = Seasons_Stats.loc[Seasons_Stats['Year']>=2000]

# %%
Two_Thousands_Stats.describe()
# Out:
#                Year           Age             G           TS%           FTr  \
# count  10204.000000  10204.000000  10204.000000  10154.000000  10151.000000
# mean    2008.784496     26.879361     48.124853      0.503367      0.301617
# std        5.144078      4.284690     26.205386      0.096449      0.234123
# min     2000.000000     18.000000      1.000000      0.000000      0.000000
# 25%     2004.000000     24.000000     24.000000      0.471000      0.179000
# 50%     2009.000000     26.000000     53.000000      0.516000      0.265000
# 75%     2013.000000     30.000000     73.000000      0.552000      0.376000
# max     2017.000000     44.000000     85.000000      1.094000      6.000000
#
#                 OWS           DWS            WS            FG           FGA  \
# count  10204.000000  10204.000000  10204.000000  10204.000000  10204.000000
# mean       1.196727      1.130155      2.328028    170.218836    378.111819
# ...

# %%
Stats_by_Player_avg = Two_Thousands_Stats.groupby(['Player']).mean()

# %%
Stats_by_Player_max = Two_Thousands_Stats.groupby(['Player']).max()

# %%
Stats_by_Player_max
# Out:
#                       Year Pos   Age   Tm     G    TS%    FTr  OWS  DWS   WS  \
# Player
# A.C. Green          2001.0  PF  37.0  MIA  82.0  0.492  0.343  1.7  3.3  5.0
# A.J. Bramlett       2000.0   C  23.0  CLE   8.0  0.190  0.000 -0.2  0.1 -0.2
# A.J. Guyton         2003.0  PG  24.0  GSW  45.0  0.495  0.111  0.4  0.0  0.3
# A.J. Hammons        2017.0   C  24.0  DAL  22.0  0.472  0.476 -0.2  0.2  0.0
# A.J. Price          2015.0  SG  28.0  WAS  57.0  0.542  0.253  1.0  1.2  2.2
# ...                    ...  ..   ...  ...   ...    ...    ...  ...  ...  ...
# Zeljko Rebraca      2006.0   C  33.0  TOT  74.0  0.625  0.519  1.4  1.9  3.3
# Zendon Hamilton     2006.0  PF  30.0  TOT  54.0  0.624  2.000  1.1  0.6  1.8
# Zoran Dragic        2015.0  SG  25.0  TOT  16.0  0.481  0.375  0.0  0.0  0.0
# Zoran Planinic      2006.0  SG  23.0  NJN  56.0  0.534  0.465  0.1  0.8  0.8
# Zydrunas Ilgauskas  2011.0   C  35.0  MIA  81.0  0.576  0.514  5.6  4.0  8.7
#
# ...

# %%
Stats_by_Player_avg
# Out:
#                            Year        Age          G       TS%       FTr  \
# Player
# A.C. Green          2000.500000  36.500000  82.000000  0.487000  0.294000
# A.J. Bramlett       2000.000000  23.000000   8.000000  0.190000  0.000000
# A.J. Guyton         2002.000000  23.000000  26.666667  0.324000  0.068333
# A.J. Hammons        2017.000000  24.000000  22.000000  0.472000  0.476000
# A.J. Price          2013.333333  26.333333  31.888889  0.435000  0.156889
# ...                         ...        ...        ...       ...       ...
# Zeljko Rebraca      2004.000000  31.000000  34.142857  0.558143  0.369286
# Zendon Hamilton     2004.125000  28.125000  18.250000  0.493375  1.132000
# Zoran Dragic        2015.000000  25.000000  10.666667  0.412667  0.211000
# Zoran Planinic      2005.000000  22.000000  49.333333  0.492000  0.401667
# Zydrunas Ilgauskas  2006.000000  30.000000  68.727273  0.527455  0.342818
#
# ...
